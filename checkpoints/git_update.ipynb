# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab
from pathlib import Path 

ROOT = "/content/drive"     # default location for the drive
drive.mount(ROOT)           # mount google drive at /content/drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJ       = "fastmri"

ALL_PROJ_PATH = Path(ROOT)/"My Drive/fastai_proj/"  # path to all projects 
GDRIVE_PATH   = ALL_PROJ_PATH/PROJ                  # path to project on GDrive
GDRIVE_PATH.mkdir(parents=True, exist_ok=True) # make dir in Gdrive to house Github

# %cd "$GDRIVE_PATH"

Path.BASE_PATH = GDRIVE_PATH
# %pwd
# Out:
# /content/drive/My Drive/fastai_proj/fastmri
# '/content/drive/My Drive/fastai_proj/fastmri'

# %%
# DELETE AFTER RUNNING!
GIT_USERNAME   = "rgologorsky" 
GIT_PASSWORD   = "XXX" # Delete this cell afterwards
GIT_TOKEN      = "XXX"  # Delte afterwards
GIT_REPO       = PROJ

GIT_PATH     = f"https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPO}.git"
GIT_URL      = f"https://{GIT_USERNAME}:{GIT_PASSWORD}@github.com/{GIT_USERNAME}/{GIT_REPO}"

# !git config --global user.email "XXX"
# !git config --global user.name "XXX"

# !git remote set-url origin "$GIT_URL"
# !git remote set-url --push origin "$GIT_URL"

# !git remote -v
# Out:
# origin	https://rgologorsky:moyGithub1!@github.com/rgologorsky/fastmri (fetch)
# origin	https://rgologorsky:moyGithub1!@github.com/rgologorsky/fastmri (push)

# %% [markdown]
# # Pull
#
# Only if ok to overwrite

# %%
pull = True
if pull: 
  # !git pull origin master --allow-unrelated-histories
# Out:
# From https://github.com/rgologorsky/fastmri
#  * branch            master     -> FETCH_HEAD
# Auto-merging common_constants_env.ipynb
# CONFLICT (add/add): Merge conflict in common_constants_env.ipynb
# Auto-merging common_archs.ipynb
# CONFLICT (add/add): Merge conflict in common_archs.ipynb
# Auto-merging 05_kspace_classifier_real_mnist.ipynb
# CONFLICT (add/add): Merge conflict in 05_kspace_classifier_real_mnist.ipynb
# Auto-merging .gitignore
# CONFLICT (add/add): Merge conflict in .gitignore
# Automatic merge failed; fix conflicts and then commit the result.

# %% [markdown]
# Uncomment if necessary!

# %%
# !git reset --hard origin/master

# %%
# !git ls-tree -r master --name-only
# Out:
# fatal: Not a valid object name master

# %%
untrack_all = False
if untrack_all:
  # !git rm -r --cached .

# %% [markdown]
# Add files

# %%
# !git add .     # Add/track files

# %%
# !git status        # Check statuses of changed files
# Out:
# On branch master
# All conflicts fixed but you are still merging.
#   (use "git commit" to conclude merge)

# %%
# !git commit -am "fix merge" # Commit msg
# Out:
# [master bff9afc] fix merge

# %%
# !git push origin master # Push changes to Github repo
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 246.56 KiB | 8.50 MiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/RGologorsky/fastmri.git
# To https://github.com/rgologorsky/fastmri
#    fb3aef9..bff9afc  master -> master

# %%
# !rm .git/index.lock

# %%
remove_lock = False
if remove_lock:
  # !rm .git/index.lock
# Out:
# rm: cannot remove '.git/index.lock': No such file or directory
