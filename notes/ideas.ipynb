# %% [markdown]
# idea
#
# transfer learning - take images from imagenet, go to k-space, crappify k-space (mask some k-space rows), re-create crappified image, GAN to fix crappified image.

# %% [markdown]
# idea - make it easy for model to learn parameters.-fastai
#
# resnet uses kernels on images -- convolutions on a sliding window of nearby pixels in kspace might not correspond to useful features.
#   - so convert subsampled k space to images and use perceptual/feature loss on subsampled k space image vs mri ground truth

# %% [markdown]
# idea - match k space freq aliasing
#
# take image, go to k space, go to phase/freq space by linear Gx and Gy gradient,  move freq higher than Nyquist limit to lower freq, then redo back to get image.

# %% [markdown]
# idea - data augmentation
#
# k space uses gradient echo which should be symmetric (symmetric dephase: dephase with Gx, undo dephase with -Gx (top of echo), then dephase against with -Gx),
# -> flip along center line should not change reconstructed MRI
#
# - add motion artifact to image or noise, go to k-space, crappify k-space (subsample), re-create crappified image, GAN to fix crappified image
